# %% [markdown]
# <a href="https://colab.research.google.com/github/minako-m/datasci112_final_project/blob/main/112_final_project_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Science 112 Final Project: Data Extraction**
# # Amira and Sophia
#
# This project explores the Cornell Movie Dialog Corpus (https://convokit.cornell.edu/documentation/movie.html).
#
# Research questions:
# 1. Has movie dialogue sentiment changed over time?
# 2. Has the sentiment of movie dialogue spoken by men versus women changed over time?
# 3. Has the sentiment of movie dialogue spoken by men to men, by men to women, by women to men, and by women to women changed over time?
#
# In this file we perform **exploratory analysis** of our data.

# %%
import nltk
nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import pandas as pd

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
import pandas as pd
movie_df = pd.read_csv('movie_dialogues.csv')
movie_df
# Out:
#         Unnamed: 0                                               text  \
# 0                0                                       They do not!
# 1                1                                        They do to!
# 2                2                                         I hope so.
# 3                3                                          She okay?
# 4                4                                          Let's go.
# ...            ...                                                ...
# 304708      304708  Lord Chelmsford seems to want me to stay back ...
# 304709      304709  I'm to take the Sikali with the main column to...
# 304710      304710                           Your orders, Mr Vereker?
# 304711      304711  Good ones, yes, Mr Vereker. Gentlemen who can ...
# 304712      304712  Colonel Durnford... William Vereker. I hear yo...
#
#        utt id_x reply_to id speaker id                  movie_name gender_x  \
# 0         L1045       L1044         u0  10 things i hate about you        f
# 1         L1044         NaN         u2  10 things i hate about you        m
# 2          L985        L984         u0  10 things i hate about you        f
# 3          L984         NaN         u2  10 things i hate about you        m
# 4          L925        L924         u0  10 things i hate about you        f
# ...         ...         ...        ...                         ...      ...
# 304708  L666371     L666370      u9030                   zulu dawn        ?
# 304709  L666370     L666369      u9034                   zulu dawn        ?
# 304710  L666369         NaN      u9030                   zulu dawn        ?
# 304711  L666257     L666256      u9030                   zulu dawn        ?
# 304712  L666256         NaN      u9034                   zulu dawn        ?
#
#         release year  rating  \
# 0               1999     6.9
# 1               1999     6.9
# 2               1999     6.9
# 3               1999     6.9
# 4               1999     6.9
# ...              ...     ...
# 304708          1979     6.4
# 304709          1979     6.4
# 304710          1979     6.4
# 304711          1979     6.4
# 304712          1979     6.4
#
#                                                     genre utt id_y gender_y  \
# 0                                   ['comedy', 'romance']    L1044        m
# 1                                   ['comedy', 'romance']      NaN      NaN
# 2                                   ['comedy', 'romance']     L984        m
# 3                                   ['comedy', 'romance']      NaN      NaN
# 4                                   ['comedy', 'romance']     L924        m
# ...                                                   ...      ...      ...
# 304708  ['action', 'adventure', 'drama', 'history', 'w...  L666370        ?
# 304709  ['action', 'adventure', 'drama', 'history', 'w...  L666369        ?
# 304710  ['action', 'adventure', 'drama', 'history', 'w...      NaN      NaN
# 304711  ['action', 'adventure', 'drama', 'history', 'w...  L666256        ?
# 304712  ['action', 'adventure', 'drama', 'history', 'w...      NaN      NaN
#
#            decade
# 0       1990-1999
# 1       1990-1999
# 2       1990-1999
# 3       1990-1999
# 4       1990-1999
# ...           ...
# 304708  1970-1979
# 304709  1970-1979
# 304710  1970-1979
# 304711  1970-1979
# 304712  1970-1979
#
# [304713 rows x 13 columns]

# %%
def get_sentiment(text):
  if pd.isna(text) :
    text = ""
  return sia.polarity_scores(text)["compound"]

movie_df['sentiment compound score'] = movie_df['text'].apply(get_sentiment)

# %% [markdown]
# ###Taking a look at the distribution of sentiments across time

# %%
import plotly.express as px

movie_df = movie_df[(movie_df["sentiment compound score"].abs() >= 0.01) & (movie_df["gender_x"] != '?')]

px.box(movie_df, x='decade', y='sentiment compound score',
              title='Average Sentiment Value Over Time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d7b18435-3df4-4ff5-9836-ef6b24d8ca99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7b18435-3df4-4ff5-9836-ef6b24d8ca99")) {                    Plotly.newPlot(                        "d7b18435-3df4-4ff5-9836-ef6b24d8ca99",                        [{"alignmentgroup":"True","hovertemplate":"decade=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999","1990-1999" ...

# %% [markdown]
# ###Exloring potential trends in sentiments across different gender groups relative to year of movie release.

# %%
male_to_male = movie_df[(movie_df["gender_x"] == "m") & (movie_df["gender_y"] == "m")]
avg_sentiment_by_year_mm = male_to_male.groupby('release year')['sentiment compound score'].mean().reset_index()
avg_sentiment_by_year_mm["group"] = "Male to male"

px.line(avg_sentiment_by_year_mm, x='release year', y='sentiment compound score',
              title='Average Sentiment Value of Males speaking to Males Over Time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a8db1c30-7562-4698-a8c5-6ea94960031b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8db1c30-7562-4698-a8c5-6ea94960031b")) {                    Plotly.newPlot(                        "a8db1c30-7562-4698-a8c5-6ea94960031b",                        [{"hovertemplate":"release year=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1931,1932,1933,1934,1936,1937,1939,1940,1941,1942,1943,1944,1945,1946,1949,1950,1953,1954,1955,1956,1957,1959,1960,1961,1963,1964,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009],"xaxis":"x","y":[0.14422473118279572,0.10749556650246306,0.04330983606557377,0.20992737430167596,0.21405128205128204,0.14437300884955753,0.169811214953271,0.07506165413533834,0.2400621212121212,0.19120183486238534,0.013071428571428569,0.3208625,0.14822891566265062,0.03634583333333333,0.05959289617486339,0.04906666666666667,0.05555982142857143,0.1336,0.11426065573770491,0.1755,0.13306190476190474,0.04940976744186047,0.12890585585585587,0.1580430463576159,0.033442481203007524,0.046271428571428574,-0.07200246913580247,0.12324838709677419,0.12045020746887967,-0.05531846153846154,0.13884634146341465,0.04385225048923679,0.03197520661157025,-0.09844405144694533,0.0636010593220339,0.04933604240282685,0.09534750830564784,0.038581366459627335,-0.1033359477124183,0.07244253611556983,0.1477954732510288,-0.021706711409395976,0.05940826833073323,0.1080847619047619,0.13612978142076504,0.05872679509632225,0.02182678936605317,0.06191642335766423,0.0642119512195122,0.06762222222222222,0.020131717171717172,0.004284679334916865,-0.027859491978609624,0.07244163319946452,0.0054746538871139495,0.00981646535282899,0.04419437531110005,0.020818064848172932,0.026180838323353297,0.019227175008397716,0.008176029962546818,0.03308364972443356,0.04238605482717521,0.04413071748878924,0.08549049255441009,-0.028273846153846153,-0.05601543209876544,0.06441594202898551,0.08691666666666667,0.03850612244897959],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#460 ...

# %%
male_to_female = movie_df[(movie_df["gender_x"] == "m") & (movie_df["gender_y"] == "f")]
avg_sentiment_by_year_mf = male_to_female.groupby('release year')['sentiment compound score'].mean().reset_index()
avg_sentiment_by_year
c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1eb7affd-0b83-4ad8-9e71-80f1e64ebd7c")) {                    Plotly.newPlot(                        "1eb7affd-0b83-4ad8-9e71-80f1e64ebd7c",                        [{"hovertemplate":"group=Female to female\u003cbr\u003erelease year=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female to female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Female to female","orientation":"v","showlegend":true,"x":[1931,1932,1933,1934,1936,1939,1941,1943,1944,1945,1949,1950,1954,1955,1957,1959,1960,1963,1968,1971,1972,1973,1975,1978,1979,1982,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[0.114225,0.10689354838709678,0.11244000000000001,0.1405360824742268,0.08455000000000001,0.16523076923076924,0.12364545454545454,0.1381918918918919,0.24903846153846154,0.01454999999999999,-0.004627272727272725,0.15606598639455782,-0.03175,-0.04215714285714286,0.5994,0.10286666666666668,0.0635391304347826,0.2095763157894737,0.22009285714285715,0.128,0.7178,0.268502,0.20083142857142855,-0.04675200000000001,0.3662181818181818,0.20360686274509804,0.12210689655172415,0.048060377358490565,0.1309796511627907,0.010681818181818183,0.0934235294117647,0.01520645161290323,0.14478235294117647,0.0474251968503937,0.20632408759124088,0.14043026315789475,0.10566683673469388,-0.05277931034482758,0.09407709497206704,0.07056030534351146,0.05763873239436619,0.1300187969924812,0.06554817708333334,0.09798591160220994,-0.027420689655172414,0.10378956521739131,0.010695454545454551,-0.163175,-0.0164054054054054,0.23143236994219651],"yaxis":"y","type":"scatter"},{"hovertemplate":"group=Female to male\u003cbr\u003erelease year=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female to male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Female to male","orientation":"v","showlegend":true,"x":[1931,1932,1933,1934,1936,1937,1939,1940,1941,1942,1943,1944,1945,1946,1949,1950,1953,1954,1955,1956,1957,1958,1959,1960,1961,1963,1964,1965,1966,1967,1968,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010],"xaxis":"x","y":[0.2452849315068493,0.166708024691358,-0.011515789473684215,0.12754978165938866,0.2405392156862745,0.1220923076923077,0.1799118881118881,0.14873333333333336,0.05505,0.09439516129032258,0.20344065934065936,0.2581421052631579,-0.10506086956521739,0.13277741935483872,0.16707777777777777,0.14550611510791367,0.1422857142857143,0.077986,0.12927386363636362,-0.10683749999999999,0.0869,0.03617642276422764,0.1738714285714286,0.12189095238095239,0.15878648648648647,0.12379186046511627,0.09880877192982457,0.19488947368421053,0.29409444444444444,0.07928958333333333,0.21352222222222222,0.1774047619047619,0.057910683760683763,0.1314093023255814,0.03976163522012579,0.15828615384615383,0.10810129310344828,0.06263082706766918,0.14748764478764478,0.11298144329896909,0.16567247191011236,0.10324705882352941,0.087356,0.06441363636363637,0.0625525974025974,0.07261849529780565,0.026340723981900453,0.12782548262548263,0.05317069597069597,0.08592832618025752,0.07992810047095762,0.08141278863232682,0.07765147928994083,0.055600000000000004,0.10912336448598133,0.1370042910447761,0.08275545212765958,0.09916376811594203,0.07218673621460507,0.07696874391431355,0.05472338516746 ...

# %% [markdown]
# As we see, there is little to no trends and/or correlations accross all of these gender groups. To make the visualisations more readable, we will try grouping by decade of release instead of year. But first, lets get more context of the distributions of different variables in our dataset.

# %% [markdown]
# ###Visualising distributions of different variables in the dataset

# %%
movie_count_by_year = pd.DataFrame(movie_df.groupby("decade")["movie_name"].nunique())
fig = px.bar(movie_count_by_year,
             labels={'decade': 'Decade', 'value': 'Number of Movies'},
             title = "Number of Unique Movies per Decade",
             color_discrete_map={'movie_name' : 'royalblue'})

fig.update_layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
    height=400, width=600,
    showlegend = False
)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="66be576a-4972-45e1-9564-9cb2977932bb" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66be576a-4972-45e1-9564-9cb2977932bb")) {                    Plotly.newPlot(                        "66be576a-4972-45e1-9564-9cb2977932bb",                        [{"alignmentgroup":"True","hovertemplate":"variable=movie_name\u003cbr\u003eDecade=%{x}\u003cbr\u003eNumber of Movies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"movie_name","marker":{"color":"royalblue","pattern":{"shape":""}},"name":"movie_name","offsetgroup":"movie_name","orientation":"v","showlegend":true,"textposition":"auto","x":["1920-1929","1930-1939","1940-1949","1950-1959","1960-1969","1970-1979","1980-1989","1990-1999","2000-2010"],"xaxis":"x","y":[1,17,15,18,18,52,111,267,101],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width ...

# %%
gender_proportion_by_year = movie_df.groupby("release year")["gender_x"].value_counts().unstack()
#gender_proportion_by_year.drop(columns = ['?'], inplace=True)
gender_proportion_by_year = gender_proportion_by_year.divide(gender_proportion_by_year.sum(axis = "columns"), axis = "rows")

fig = px.bar(gender_proportion_by_year, barmode = "stack",
       labels={'release year': 'Release Year', 'value': 'Distribution of genders'},
       title = "Distribution of genders of speakers over time",
       color_discrete_map={'f': 'salmon', 'm': 'royalblue'})

fig.update_layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0e181606-028e-4902-9823-0e4bd930ce66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e181606-028e-4902-9823-0e4bd930ce66")) {                    Plotly.newPlot(                        "0e181606-028e-4902-9823-0e4bd930ce66",                        [{"alignmentgroup":"True","hovertemplate":"gender_x=f\u003cbr\u003eRelease Year=%{x}\u003cbr\u003eDistribution of genders=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"f","marker":{"color":"salmon","pattern":{"shape":""}},"name":"f","offsetgroup":"f","orientation":"v","showlegend":true,"textposition":"auto","x":[1927,1931,1932,1933,1934,1936,1937,1939,1940,1941,1942,1943,1944,1945,1946,1949,1950,1953,1954,1955,1956,1957,1958,1959,1960,1961,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010],"xaxis":"x","y":[1.0,0.2911111111111111,0.3090079817559863,0.28205128205128205,0.44300278035217794,0.24861878453038674,0.0443213296398892,0.40562248995983935,0.32706222865412443,0.499001996007984,0.17083333333333334,0.3905109489051095,0.7083333333333334,0.2440944881889764,0.19480519480519481,0.26,0.5913410770855333,0.12714776632302405,0.33826247689463956,0.37425742574257426,0.10714285714285714,0.21645021645021645,0.5533980582524272,0.2553191489361702,0.35543478260869565,0.27510917030567683,0.3467741935483871,0.09247027741083223,0.5423728813559322,0.11442786069651742,0.311336717428088,0.11574074074074074,null,0.26851851851851855,0.24891146589259797,0.25239005736137665,0.27419354838709675,0.15883859948761742,0.22216035634743875,0.18792710706150342,0.33229166666666665,0.26251896813353565,0.1603098927294398,0.2375,0.19402985074626866,0.2837022132796781,0.27239709443099275,0.3523545706371191,0.33798604187437686,0.3901198692335634,0.37719891745602163,0.30080296479308216,0.31966759002770084,0.34438377535101405,0.3407119353873766,0.23573762251822067,0.2510572856593618,0.3379174852652259,0.25113524185587366,0.22950526879799965,0.2896683673469388,0.29218426501035194,0.2747973755306831,0.3170190550770034,0.32962245885769603,0.258819756254009,0.2805035506778567,0.27964547677261614,0.2844702467343977,0.3078078078078078,0.576837416481069,0.1875,0.362565445026178,0.35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender_x=m\u003cbr\u003eRelease Year=%{x}\u003cbr\u003eDistribution of genders=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"m","marker":{"color":"royalblue","pattern":{"shape":""}},"name":"m","offsetgroup":"m","orientation":"v","showlegend":true,"textposition":"auto","x":[1927,1931,1932,1933,1934,1936,1937,1939,1940,1941,1942,1943,1944,1945,1946,1949,1950,1953,1954,1955,1956,1957,1958,1959,1960,1961,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010],"xaxis":"x","y":[null,0.7088888888888889,0.6909920182440137,0.717948717948718,0.556997219647822,0.7513812154696132,0.9556786703601108,0.5943775100401606,0.6729377713458755,0.500998003992016,0.8291666666666667,0.6094890510948905,0.2916666666666667,0.7559055118110236,0.8051948051948052,0.74,0.40865892291446676,0.872852233676976,0.6617375231053605,0.6257425742574257,0.8928571428571429,0.7835497835497836,0.44660194174757284,0.7446808510638298,0.6445652173913043,0.7248908296943232,0.6532258064516129,0.9075297225891678,0.4576271186440678,0.8855721393034826,0.688663282571912,0.8842592592592593,1.0,0.7314814814814815,0.7510885341074 ...

# %%
temp = movie_df["gender_x"].value_counts(normalize = True)
fig = px.bar(temp,
             labels={'value': 'Proportion', 'm': 'Male', 'f': 'Female', 'index' : 'Gender'},
             title = "Overall Distribution of Genders",
             color_discrete_map={'f': 'salmon', 'm': 'royalblue'})
fig.update_layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
    height=400, width=300,
    showlegend = False
)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f1e462d4-eeeb-4feb-890a-e5fc17d5f033" class="plotly-graph-div" style="height:400px; width:300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1e462d4-eeeb-4feb-890a-e5fc17d5f033")) {                    Plotly.newPlot(                        "f1e462d4-eeeb-4feb-890a-e5fc17d5f033",                        [{"alignmentgroup":"True","hovertemplate":"variable=proportion\u003cbr\u003egender_x=%{x}\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"proportion","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"proportion","offsetgroup":"proportion","orientation":"v","showlegend":true,"textposition":"auto","x":["m","f"],"xaxis":"x","y":[0.7041923864231422,0.29580761357685775],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{ ...

# %% [markdown]
# ###Exploring trends in dialogue sentiment accross different gender groups relative to decade of release.

# %%
male_to_male = movie_df[(movie_df["gender_x"] == "m") & (movie_df["gender_y"] == "m")]
avg_sentiment_by_year_mm = male_to_male.groupby('decade')['sentiment compound score'].mean().reset_index()
avg_sentiment_by_year_mm["group"] = "Male to male"

male_to_female = movie_df[(movie_df["gender_x"] == "m") & (movie_df["gender_y"] == "f")]
avg_sentiment_by_year_mf = male_to_female.groupby('decade')['sentiment compound score'].mean().reset_index()
avg_sentiment_by_year_mf["group"] = "Male to female"

female_to_male = movie_df[(movie_df["gender_x"] == "f") & (movie_df["gender_y"] == "m")]
avg_sentiment_by_year_fm = female_to_male.groupby('decade')['sentiment compound score'].mean().reset_index()
avg_sentiment_by_year_fm["group"] = "Female to male"

female_to_female = movie_df[(movie_df["gender_x"] == "f") & (movie_df["gender_y"] == "f")]
avg_sentiment_by_year_ff = female_to_female.groupby('decade')['sentiment compound score'].mean().reset_index()
avg_sentiment_by_year_ff["group"] = "Female to female"

df = pd.concat([avg_sentiment_by_year_ff, avg_sentiment_by_year_fm, avg_sentiment_by_year_mf, avg_sentiment_by_year_mm], ignore_index=True)

px.line(df, x='decade', y='sentiment compound score', color='group',
              title='Sentiment Scores of Utterances between Males and Females by Decade')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="63761f3c-632c-4879-a51d-99cf68139319" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63761f3c-632c-4879-a51d-99cf68139319")) {                    Plotly.newPlot(                        "63761f3c-632c-4879-a51d-99cf68139319",                        [{"hovertemplate":"group=Female to female\u003cbr\u003edecade=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female to female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Female to female","orientation":"v","showlegend":true,"x":["1920-1929","1930-1939","1940-1949","1950-1959","1960-1969","1970-1979","1980-1989","1990-1999","2000-2010"],"xaxis":"x","y":[null,0.18694452554744526,0.21908666666666665,0.035746153846153844,0.3147131147540984,0.25898923076923075,0.11046508538899431,0.1373313777777778,0.161655223880597],"yaxis":"y","type":"scatter"},{"hovertemplate":"group=Female to male\u003cbr\u003edecade=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female to male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Female to male","orientation":"v","showlegend":true,"x":["1920-1929","1930-1939","1940-1949","1950-1959","1960-1969","1970-1979","1980-1989","1990-1999","2000-2010"],"xaxis":"x","y":[null,0.2060154761904762,0.18081010638297873,0.16483785310734464,0.21319914529914533,0.17736613995485329,0.11966140625,0.11531400394477319,0.1439406561218512],"yaxis":"y","type":"scatter"},{"hovertemplate":"group=Male to female\u003cbr\u003edecade=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male to female","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Male to female","orientation":"v","showlegend":true,"x":["1920-1929","1930-1939","1940-1949","1950-1959","1960-1969","1970-1979","1980-1989","1990-1999","2000-2010"],"xaxis":"x","y":[null,0.22030776699029128,0.15201548913043478,0.20767095890410958,0.1657552036199095,0.18219702315325248,0.14898206931190355,0.13025258318739052,0.13876242074927955],"yaxis":"y","type":"scatter"},{"hovertemplate":"group=Male to male\u003cbr\u003edecade=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male to male","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Male to male","orientation":"v","showlegend":true,"x":["1920-1929","1930-1939","1940-1949","1950-1959","1960-1969","1970-1979","1980-1989","1990-1999","2000-2010"],"xaxis":"x","y":[null,0.18448592375366568,0.1982176165803109,0.14159471458773784,0.11335635593220339,0.09245353862776877,0.10005953639690932,0.05563903371567605,0.07609213701829506],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0. ...

# %%
male_utterances = movie_df[(movie_df["gender_x"] == "m")]
female_utterances = movie_df[(movie_df["gender_x"] == "f")]

avg_sentiment_by_year_male = male_utterances.groupby('decade')['sentiment compound score'].mean().reset_index()
avg_sentiment_by_year_male["gender"] = "male"
avg_sentiment_by_year_female = female_utterances.groupby('decade')['sentiment compound score'].mean().reset_index()
avg_sentiment_by_year_female["gender"] = "female"

df = pd.concat([avg_sentiment_by_year_male, avg_sentiment_by_year_female], ignore_index=True)

px.line(df, x='decade', y='sentiment compound score', color='gender',
              title='Sentiment Scores of Utterances of Males and Females')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="74bf47cb-c4be-4dcf-8d7b-cc7caf0cc52f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74bf47cb-c4be-4dcf-8d7b-cc7caf0cc52f")) {                    Plotly.newPlot(                        "74bf47cb-c4be-4dcf-8d7b-cc7caf0cc52f",                        [{"hovertemplate":"gender=male\u003cbr\u003edecade=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","orientation":"v","showlegend":true,"x":["1920-1929","1930-1939","1940-1949","1950-1959","1960-1969","1970-1979","1980-1989","1990-1999","2000-2010"],"xaxis":"x","y":[null,0.20438555176336745,0.1696609211126311,0.15198451345755692,0.1269968473255402,0.12085166364186327,0.11111819632881084,0.07899981358842285,0.10471935604642456],"yaxis":"y","type":"scatter"},{"hovertemplate":"gender=female\u003cbr\u003edecade=%{x}\u003cbr\u003esentiment compound score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","orientation":"v","showlegend":true,"x":["1920-1929","1930-1939","1940-1949","1950-1959","1960-1969","1970-1979","1980-1989","1990-1999","2000-2010"],"xaxis":"x","y":[0.22083333333333333,0.2014980670835702,0.19081303191489363,0.14791867739052728,0.18798119658119658,0.16351828713280928,0.11328644683323649,0.1129583151053059,0.1231779010097666],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887 ...

# %% [markdown]
# ###Conclusion
#
# From initial exploratory analysis, we saw that there are barely any noticable trends in sentiment scores in the dataset. We propose a hypothesis that this is because the sentiment scores are too neutral due to such words like stopwords. We will explore this hypothesis in the 'Analysis' file.
